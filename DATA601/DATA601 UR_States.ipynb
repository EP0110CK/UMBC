# %%
pip install pandas requests fredapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
from fredapi import Fred

# %%
API_KEY = 'UNRATE'

# %%
url = f'https://api.stlouisfed.org/fred/category?category_id=125&api_key=abcdefghijklmnopqrstuvwxyz123456&file_type=json'
response = requests.get(url)

# %%
MDUR = requests.get('https://fred.stlouisfed.org/series/MDUR')
PAUR = requests.get('https://fred.stlouisfed.org/series/PAUR')
VAUR = requests.get('https://fred.stlouisfed.org/series/VAUR')

# %%
MD = pd.DataFrame(MDUR)
PA = pd.DataFrame(PAUR)
VA = pd.DataFrame(VAUR)

# %%
print(MD)
print(PA)
print(VA)
# Out:
#                                                      0
# 0    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 1    b'             <title>Unemployment Rate in Mar...
# 2    b' []\n    </script>\n\n    <!-- Google Tag Ma...
# 3    b"sh({\n        'gtm.start':\n          new Da...
# 4    b"       j = d.createElement(s), dl = l != 'da...
# ..                                                 ...
# 571  b'ript>\n<script defer src=/assets/clipboard.j...
# 572  b'847.fileDownload.min.js></script>\n<script s...
# 573  b'\n  let today = new Date().toLocaleString("e...
# 574  b' $("#cit-date").html(today);\n</script>\n\n<...
# 575  b'tylesheet">\n</head>\n<script src=/assets/re...
#
# [576 rows x 1 columns]
#                                                      0
# 0    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 1    b'             <title>Unemployment Rate in Pen...
# 2    b'er = []\n    </script>\n\n    <!-- Google Ta...
# 3    b"].push({\n        'gtm.start':\n          ne...
# ...

# %%
fred = Fred(api_key = 'd7841430d5388f5c4f78714ce1baf152')

# %%
series_ids = ['UNRATE', 'ALUR', 'AKUR', 'AZUR', 'ARUR', 'CAUR', 'COUR', 'CTUR', 'DEUR', 'FLUR', 'GAUR', 'HIUR', 'IDUR', 'ILUR', 'INUR', 'IAUR', 'KSUR', 'KYUR', 'LAUR', 'MEUR', 'MDUR', 'MAUR', 'MIUR', 'MNUR', 'MSUR', 'MOUR', 'MTUR', 'NEUR', 'NVUR', 'NHUR', 'NJUR', 'NMUR', 'NYUR', 'NCUR', 'NDUR', 'OHUR', 'OKUR', 'ORUR', 'PAUR', 'RIUR', 'SCUR', 'SDUR', 'TNUR', 'TXUR', 'UTUR', 'VTUR', 'VAUR', 'WAUR', 'WVUR', 'WIUR', 'WYUR']
dataframes = {}

# %%
for series_id in series_ids:
    dataframes[series_id] = fred.get_series(series_id)

# %%
df = pd.DataFrame()

for series_id, dataframe in dataframes.items():
    if df.empty:
        df = dataframe.to_frame(name=series_id)
    else:
        df = pd.merge(df, dataframe.to_frame(name=series_id), left_index=True, right_index=True, how='outer')

# %%
display(df)
# Out:
#             UNRATE  ALUR  AKUR  AZUR  ARUR  CAUR  COUR  CTUR  DEUR  FLUR  ...  \
# 1948-01-01     3.4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1948-02-01     3.8   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1948-03-01     4.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1948-04-01     3.9   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1948-05-01     3.5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 2024-05-01     4.0   3.0   4.5   3.4   3.4   5.2   3.8   4.3   3.9   3.3  ...
# 2024-06-01     4.1   2.9   4.5   3.3   3.3   5.2   3.8   3.9   4.0   3.3  ...
# 2024-07-01     4.3   2.8   4.5   3.4   3.3   5.2   3.9   3.6   4.1   3.3  ...
# 2024-08-01     4.2   2.8   4.6   3.4   3.3   5.3   4.0   3.4   4.2   3.3  ...
# 2024-09-01     4.1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
# ...
